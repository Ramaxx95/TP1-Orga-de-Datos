# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_frame = pd.read_csv('Entrenamieto_ECI_2020.csv')
data_frame.Account_Created_Date = pd.to_datetime(data_frame.Account_Created_Date)
data_frame.Actual_Delivery_Date = pd.to_datetime(data_frame.Actual_Delivery_Date)
data_frame.Opportunity_Created_Date = pd.to_datetime(data_frame.Opportunity_Created_Date)
data_frame.Quote_Expiry_Date = pd.to_datetime(data_frame.Quote_Expiry_Date)
data_frame.Last_Modified_Date = pd.to_datetime(data_frame.Last_Modified_Date)
data_frame.Planned_Delivery_Start_Date = pd.to_datetime(data_frame.Planned_Delivery_Start_Date)
data_frame
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0      27761      EMEA        None                                   1
# 1      27760      EMEA        None                                   0
# 2      27446  Americas  NW America                                   0
# 3      16808  Americas  NW America                                   1
# 4      16805  Americas  NW America                                   1
# ...      ...       ...         ...                                 ...
# 16942   8781      EMEA     Austria                                   1
# 16943   8786      EMEA     Austria                                   1
# 16944   8792      EMEA     Austria                                   1
# 16945  28561  Americas  NE America                                   1
# 16946  28318  Americas  NE America                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# ...

# %%
oportunidades_cerradas = data_frame[( (data_frame.Stage == 'Closed Won') | (data_frame.Stage == 'Closed Lost')) & (data_frame.Region == 'EMEA') ]
oportunidades_cerradas
# Out:
#           ID Region       Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0      27761   EMEA            None                                   1
# 1      27760   EMEA            None                                   0
# 62     18557   EMEA           Italy                                   1
# 63     13392   EMEA         Germany                                   0
# 66     18491   EMEA  United Kingdom                                   0
# ...      ...    ...             ...                                 ...
# 16938  28767   EMEA         Germany                                   1
# 16939  18324   EMEA          Norway                                   1
# 16942   8781   EMEA         Austria                                   1
# 16943   8786   EMEA         Austria                                   1
# 16944   8792   EMEA         Austria                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# ...

# %%
oportunidades_ganadas_EMEA = data_frame[(data_frame.Stage == 'Closed Won') & (data_frame.Region == 'EMEA')]
oportunidades_ganadas_EMEA
# Out:
#           ID Region       Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 1      27760   EMEA            None                                   0
# 63     13392   EMEA         Germany                                   0
# 66     18491   EMEA  United Kingdom                                   0
# 67     18494   EMEA  United Kingdom                                   0
# 70     19680   EMEA  United Kingdom                                   0
# ...      ...    ...             ...                                 ...
# 16937  17683   EMEA         Germany                                   0
# 16939  18324   EMEA          Norway                                   1
# 16942   8781   EMEA         Austria                                   1
# 16943   8786   EMEA         Austria                                   1
# 16944   8792   EMEA         Austria                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# ...

# %%
oportunidades_perdidas_EMEA = data_frame[(data_frame.Stage == 'Closed Lost') & (data_frame.Region == 'EMEA')]
oportunidades_perdidas_EMEA
# Out:
#           ID Region       Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0      27761   EMEA            None                                   1
# 62     18557   EMEA           Italy                                   1
# 68      4920   EMEA  United Kingdom                                   1
# 69     17590   EMEA         Germany                                   1
# 78      4904   EMEA     UAE (Dubai)                                   1
# ...      ...    ...             ...                                 ...
# 16857  14759   EMEA         Germany                                   0
# 16928  19906   EMEA          France                                   0
# 16929  12703   EMEA          France                                   1
# 16932  15785   EMEA         Germany                                   0
# 16938  28767   EMEA         Germany                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# ...

# %%
anios_oportunidades_cerradas = oportunidades_cerradas.Opportunity_Created_Date.dt.year.value_counts().to_frame( name = 'Cantidad oportunidades cerradas').sort_index()
anios_oportunidades_cerradas
# Out:
#       Cantidad oportunidades cerradas
# 2013                                1
# 2014                                4
# 2015                              198
# 2016                             1103
# 2017                             1898
# 2018                             1456

# %%
anios_oportunidades_ganadas = oportunidades_ganadas_EMEA.Opportunity_Created_Date.dt.year.value_counts().to_frame( name = 'Cantidad oportunidades ganadas').sort_index()
anios_oportunidades_ganadas
# Out:
#       Cantidad oportunidades ganadas
# 2014                               1
# 2015                              73
# 2016                             461
# 2017                            1173
# 2018                             763

# %%
anios_oportunidades_perdidas = oportunidades_perdidas_EMEA.Opportunity_Created_Date.dt.year.value_counts().to_frame( name = 'Cantidad oportunidades perdidas').sort_index()
anios_oportunidades_perdidas
# Out:
#       Cantidad oportunidades perdidas
# 2013                                1
# 2014                                3
# 2015                              125
# 2016                              642
# 2017                              725
# 2018                              693

# %%
lista_anios = [anios_oportunidades_ganadas, anios_oportunidades_cerradas, anios_oportunidades_perdidas]
anios_totales =  pd.concat(lista_anios, join = 'outer', axis = 1).fillna(0)
#Limpieza de datos de poca importancia para el data frame para que no afecte la representacion del grafico
anios_totales.drop(index = [2013, 2014], inplace = True)
anios_totales
# Out:
#       Cantidad oportunidades ganadas  Cantidad oportunidades cerradas  \
# 2015                            73.0                              198
# 2016                           461.0                             1103
# 2017                          1173.0                             1898
# 2018                           763.0                             1456
#
#       Cantidad oportunidades perdidas
# 2015                              125
# 2016                              642
# 2017                              725
# 2018                              693

# %%
anios_totales.plot.bar( title = 'Oportunidades totales, ganadas y perdidas por anio creadas' , rot = 65, figsize = ((20,10)), color = ['green', 'blue', 'red'])
ax=plt.gca()
ax.set_ylabel('Cantidad de casos cerrados');
ax.set_xlabel('Años')
plt.show()

# %%
paises_totales = oportunidades_cerradas.Billing_Country.value_counts().to_frame(name = 'Oportunidades totales')
paises_totales.head(10)
# Out:
#                 Oportunidades totales
# Germany                          1953
# Netherlands                       563
# France                            393
# Spain                             315
# Italy                             293
# United Kingdom                    279
# Belgium                           226
# Austria                           145
# Luxembourg                        136
# Poland                             52

# %%
paises_ganados =  oportunidades_ganadas_EMEA.Billing_Country.value_counts()
paises_ganados = paises_ganados.to_frame( name = 'Oportunidades Ganadas')
paises_ganados.head(10)
# Out:
#                 Oportunidades Ganadas
# Germany                          1121
# Netherlands                       315
# Spain                             192
# Italy                             152
# United Kingdom                    127
# Austria                           122
# Belgium                           119
# France                            111
# Luxembourg                         89
# Cyprus                             34

# %%
paises_ganados.plot(kind= 'bar',figsize =(16,8), rot =65, title = 'Top 10 de paises con casos ganados a lo largo de los anios', color = 'green');
ax=plt.gca()
ax.set_ylabel('oportunidades cerradas ganadas');
ax.set_xlabel('Paises')
plt.show()

# %%
paises_perdidos =  oportunidades_perdidas_EMEA.Billing_Country.value_counts()
paises_perdidos = paises_perdidos.to_frame( name =  'Oportunidades perdidas')
paises_perdidos.head(10)
# Out:
#                 Oportunidades perdidas
# Germany                            832
# France                             282
# Netherlands                        248
# United Kingdom                     152
# Italy                              141
# Spain                              123
# Belgium                            107
# Luxembourg                          47
# Poland                              36
# Austria                             23

# %%
paises_perdidos.plot(kind= 'bar',figsize =(16,8), rot =65, title = 'Top 10 paises con casos cerrados perdidas de EMEA', color = 'red');
ax=plt.gca()
ax.set_ylabel('oportunidades cerradas perdidas');
ax.set_xlabel('Paises')
plt.show()

# %%
lista_paises = [paises_ganados, paises_totales, paises_perdidos]
top5_paises = pd.concat(lista_paises, join = 'outer', axis = 1).fillna(0).nlargest(5, 'Oportunidades Ganadas')
top5_paises
# Out:
#                 Oportunidades Ganadas  Oportunidades totales  \
# Germany                        1121.0                   1953
# Netherlands                     315.0                    563
# Spain                           192.0                    315
# Italy                           152.0                    293
# United Kingdom                  127.0                    279
#
#                 Oportunidades perdidas
# Germany                          832.0
# Netherlands                      248.0
# Spain                            123.0
# Italy                            141.0
# United Kingdom                   152.0

# %%
top5_paises.plot.barh( title = 'Top 5 paises con casos cerrados en EMEA', rot = 0 ,figsize = ((15,11)), color = ['green', 'blue', 'red'])
ax=plt.gca()
ax.set_ylabel('Paises');
ax.set_xlabel('Cantidad casos')
plt.show()

# %%
anio_2017 = oportunidades_cerradas[ oportunidades_cerradas.Opportunity_Created_Date.dt.year == 2017]
anio_2017.Stage.value_counts().to_frame().plot.pie(title = 'Distribucion de casos en 2017 en la Region de EMEA', y = 'Stage', figsize = (11,6), autopct='%1.0f%%')
plt.show()

# %%
paises_cerrados_2017 = anio_2017.Billing_Country.value_counts().to_frame( name = 'Oportunidades cerradas').nlargest(10, 'Oportunidades cerradas')
paises_cerrados_2017
# Out:
#                 Oportunidades cerradas
# Germany                            811
# Netherlands                        212
# Spain                              143
# Italy                              140
# France                             125
# United Kingdom                      93
# Belgium                             92
# Austria                             74
# Luxembourg                          64
# Poland                              29

# %%
paises_cerrados_2017.plot(kind= 'bar',figsize =(16,8), rot =65, title = 'Paises con casos cerrados creados en 2017', color = 'blue');
ax=plt.gca()
ax.set_ylabel('Oportunidades cerradas');
ax.set_xlabel('Paises')
plt.show()

# %%
anio_2017_ganados = anio_2017[anio_2017.Stage == 'Closed Won']
grafico_2017_ganados = anio_2017_ganados.Billing_Country.value_counts().to_frame( name = 'Paises con oportunidades ganadas').nlargest(10, 'Paises con oportunidades ganadas')
grafico_2017_ganados.plot(kind= 'bar',figsize =(16,8), rot =65, title = 'Paises con casos ganados creados en 2017', color = 'green');
ax=plt.gca()
ax.set_ylabel('Oportunidades cerradas ganadas');
ax.set_xlabel('Paises')
plt.show()

# %%
anio_2017_perdidos = anio_2017[anio_2017.Stage == 'Closed Lost']
grafico_2017_perdidos_pais = anio_2017_perdidos.Territory.value_counts().to_frame( name = 'Paises con oportunidades ganadas').nlargest(10, 'Paises con oportunidades ganadas')
grafico_2017_perdidos_pais.plot(kind= 'bar',figsize =(16,8), rot =65, title = 'Paises con casos perdidos creados en 2017', color = 'red');
ax=plt.gca()
ax.set_ylabel('Oportunidades cerradas perdidas');
ax.set_xlabel('Paises')
plt.show()

# %%
anio_2017_vendedores_totales = anio_2017.Account_Owner.value_counts().to_frame(name = 'Oportunidades Cerradas')
anio_2017_vendedores_totales
# Out:
#                 Oportunidades Cerradas
# Person_Name_13                     588
# Person_Name_18                     416
# Person_Name_4                      304
# Person_Name_2                      174
# Person_Name_42                     153
# Person_Name_16                     149
# Person_Name_51                      35
# Person_Name_62                      30
# Person_Name_41                      24
# Person_Name_14                      19
# Person_Name_58                       2
# Person_Name_8                        1
# Person_Name_10                       1
# Person_Name_39                       1
# Person_Name_23                       1

# %%
anio_2017_vendedores_ganados = anio_2017_ganados.Account_Owner.value_counts().to_frame( name = 'Oportunidades Ganadas')
anio_2017_vendedores_ganados
# Out:
#                 Oportunidades Ganadas
# Person_Name_13                    427
# Person_Name_18                    259
# Person_Name_4                     161
# Person_Name_42                    111
# Person_Name_2                     110
# Person_Name_16                     60
# Person_Name_62                     18
# Person_Name_51                     13
# Person_Name_14                     11
# Person_Name_41                      3

# %%
anio_2017_vendedores_perdidos = anio_2017_perdidos.Account_Owner.value_counts().to_frame( name = 'Oportunidades Perdidas')
anio_2017_vendedores_perdidos
# Out:
#                 Oportunidades Perdidas
# Person_Name_13                     161
# Person_Name_18                     157
# Person_Name_4                      143
# Person_Name_16                      89
# Person_Name_2                       64
# Person_Name_42                      42
# Person_Name_51                      22
# Person_Name_41                      21
# Person_Name_62                      12
# Person_Name_14                       8
# Person_Name_58                       2
# Person_Name_39                       1
# Person_Name_8                        1
# Person_Name_23                       1
# Person_Name_10                       1

# %%
# Para un grafico de barras agrupado lo que vamos a hacer es a esos 3 value counts lo vamos a llevar a un data frame y ponerlos todos en un mismo lugar
frames = [anio_2017_vendedores_ganados, anio_2017_vendedores_totales, anio_2017_vendedores_perdidos]
grafico =  pd.concat(frames, join = 'outer', axis = 1).fillna(0).nlargest(5, 'Oportunidades Ganadas')
grafico
# Out:
#                 Oportunidades Ganadas  Oportunidades Cerradas  \
# Person_Name_13                  427.0                     588
# Person_Name_18                  259.0                     416
# Person_Name_4                   161.0                     304
# Person_Name_42                  111.0                     153
# Person_Name_2                   110.0                     174
#
#                 Oportunidades Perdidas
# Person_Name_13                     161
# Person_Name_18                     157
# Person_Name_4                      143
# Person_Name_42                      42
# Person_Name_2                       64

# %%
grafico.plot.barh( title = 'Top 5 vendedores en el 2017 por cantidad de oportunidades ganadas' , rot = 65, figsize = ((15,10)), color = ['green', 'blue', 'red'])
ax=plt.gca()
ax.set_ylabel('Vendedores');
ax.set_xlabel('Oportunidades cerradas')
plt.show()

# %%
productos_mejor_team_2017 = anio_2017[anio_2017.Account_Owner == 'Person_Name_13'].Billing_Country.value_counts().to_frame( name = 'Cantidad de productos vendidos')
productos_mejor_team_2017
# Out:
#               Cantidad de productos vendidos
# Germany                                  468
# Austria                                   72
# Switzerland                               12
# Turkey                                    10
# Norway                                    10
# Sweden                                     8
# South Africa                               5
# Denmark                                    2
# Bulgaria                                   1

# %%
productos_mejor_team_2017.plot.pie(y = 'Cantidad de productos vendidos')
plt.show()
