# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_frame = pd.read_csv('Entrenamieto_ECI_2020.csv')
data_frame.Account_Created_Date = pd.to_datetime(data_frame.Account_Created_Date)
data_frame.Actual_Delivery_Date = pd.to_datetime(data_frame.Actual_Delivery_Date)
data_frame.Opportunity_Created_Date = pd.to_datetime(data_frame.Opportunity_Created_Date)
data_frame.Quote_Expiry_Date = pd.to_datetime(data_frame.Quote_Expiry_Date)
data_frame.Last_Modified_Date = pd.to_datetime(data_frame.Last_Modified_Date)
data_frame.Planned_Delivery_Start_Date = pd.to_datetime(data_frame.Planned_Delivery_Start_Date)
data_frame
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0      27761      EMEA        None                                   1
# 1      27760      EMEA        None                                   0
# 2      27446  Americas  NW America                                   0
# 3      16808  Americas  NW America                                   1
# 4      16805  Americas  NW America                                   1
# ...      ...       ...         ...                                 ...
# 16942   8781      EMEA     Austria                                   1
# 16943   8786      EMEA     Austria                                   1
# 16944   8792      EMEA     Austria                                   1
# 16945  28561  Americas  NE America                                   1
# 16946  28318  Americas  NE America                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# ...

# %%
oportunidades_cerradas = data_frame[ ((data_frame.Stage == 'Closed Lost') | (data_frame.Stage == 'Closed Won')) & ( data_frame.Region ==  'Middle East') ]
oportunidades_cerradas
# Out:
#           ID       Region    Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 745     5700  Middle East       Kuwait                                   1
# 994    18723  Middle East          KSA                                   1
# 995     6816  Middle East          KSA                                   1
# 998     6822  Middle East         None                                   1
# 999     6839  Middle East  UAE (Dubai)                                   1
# ...      ...          ...          ...                                 ...
# 15406  13020  Middle East       Jordan                                   1
# 15491   5985  Middle East       Jordan                                   1
# 15547   8780  Middle East  UAE (Dubai)                                   1
# 15711  12960  Middle East       Jordan                                   1
# 15879  12949  Middle East       Jordan                                   1
#
# ...

# %%
oportunidades_ganadas_middle_east = data_frame[(data_frame.Stage == 'Closed Won') & (data_frame.Region == 'Middle East')]
oportunidades_ganadas_middle_east
# Out:
#           ID       Region     Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 1590    9750  Middle East        Jordan                                   1
# 1591    9756  Middle East        Jordan                                   1
# 1787   13109  Middle East          None                                   1
# 1788   13115  Middle East          None                                   1
# 1789   13120  Middle East          None                                   1
# 4673   13533  Middle East          None                                   1
# 4675   13623  Middle East  Saudi Arabia                                   1
# 4754   23554  Middle East           KSA                                   1
# 5121   14822  Middle East   UAE (Dubai)                                   1
# 5402   13628  Middle East  UAE (Others)                                   1
# 6579   15017  Middle East        Jordan                                   1
# ...

# %%
oportunidades_perdidas_middle_east = data_frame[(data_frame.Stage == 'Closed Lost') & (data_frame.Region == 'Middle East')]
oportunidades_perdidas_middle_east
# Out:
#           ID       Region    Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 745     5700  Middle East       Kuwait                                   1
# 994    18723  Middle East          KSA                                   1
# 995     6816  Middle East          KSA                                   1
# 998     6822  Middle East         None                                   1
# 999     6839  Middle East  UAE (Dubai)                                   1
# ...      ...          ...          ...                                 ...
# 15171   9723  Middle East       Jordan                                   1
# 15406  13020  Middle East       Jordan                                   1
# 15491   5985  Middle East       Jordan                                   1
# 15547   8780  Middle East  UAE (Dubai)                                   1
# 15711  12960  Middle East       Jordan                                   1
#
# ...

# %%
paises_totales = oportunidades_cerradas.Billing_Country.value_counts().to_frame(name = 'Casos totales')
paises_totales
# Out:
#                       Casos totales
# Jordan                          100
# United Arab Emirates             16
# Pakistan                         11
# Lebanon                          10
# Saudi Arabia                      8
# Germany                           5
# South Africa                      5
# Kuwait                            3
# Egypt                             3
# India                             2
# Palestine                         2
# Bahrain                           1
# France                            1
# Italy                             1
# Libya                             1
# Japan                             1

# %%
paises_ganados = oportunidades_ganadas_middle_east.Billing_Country.value_counts().to_frame(name = 'Casos ganados')
paises_ganados
# Out:
#                       Casos ganados
# Jordan                           35
# Pakistan                          4
# Lebanon                           3
# United Arab Emirates              3
# South Africa                      3
# Bahrain                           1
# Saudi Arabia                      1

# %%
paises_perdidos = oportunidades_perdidas_middle_east.Billing_Country.value_counts().to_frame(name = 'Casos perdidos')
paises_perdidos
# Out:
#                       Casos perdidos
# Jordan                            65
# United Arab Emirates              13
# Pakistan                           7
# Lebanon                            7
# Saudi Arabia                       7
# Germany                            5
# Kuwait                             3
# Egypt                              3
# India                              2
# Palestine                          2
# South Africa                       2
# France                             1
# Italy                              1
# Japan                              1
# Libya                              1

# %%
lista_paises = [paises_ganados, paises_totales, paises_perdidos]
top5_paises = pd.concat(lista_paises, join= 'outer', axis = 1).fillna(0).nlargest(5, 'Casos ganados')
top5_paises
# Out:
#                       Casos ganados  Casos totales  Casos perdidos
# Jordan                         35.0            100            65.0
# Pakistan                        4.0             11             7.0
# Lebanon                         3.0             10             7.0
# United Arab Emirates            3.0             16            13.0
# South Africa                    3.0              5             2.0

# %%
top5_paises.plot.barh( title = 'Top 5 paises con casos ganados Middle East', rot = 0 ,figsize = ((15,11)), color = ['green', 'blue', 'red'])
ax=plt.gca()
ax.set_ylabel('Paises');
ax.set_xlabel('Cantidad casos')
plt.show()

# %%
oportunidades_ganadas_middle_east_df_paises_df =  oportunidades_ganadas_middle_east.Billing_Country.value_counts()
oportunidades_ganadas_middle_east_df_paises_df = oportunidades_ganadas_middle_east_df_paises_df.to_frame()
oportunidades_ganadas_middle_east_df_paises_df
# Out:
#                       Billing_Country
# Jordan                             35
# Pakistan                            4
# Lebanon                             3
# United Arab Emirates                3
# South Africa                        3
# Bahrain                             1
# Saudi Arabia                        1

# %%
oportunidades_ganadas_middle_east_df_paises_df.plot(kind= 'bar',figsize =(16,8), rot =0, title = 'Paises con casos cerrados ganados del middle east', color = (0.7, 0.2, 0.4, 0.6));
ax=plt.gca()
ax.set_ylabel('oportunidades cerradas perdidas');
ax.set_xlabel('Paises')
plt.show()

# %%
oportunidades_perdidas_middle_east_df_paises_df =  oportunidades_perdidas_middle_east.Billing_Country.value_counts()
oportunidades_perdidas_middle_east_df_paises_df = oportunidades_perdidas_middle_east_df_paises_df.to_frame()
oportunidades_perdidas_middle_east_df_paises_df
# Out:
#                       Billing_Country
# Jordan                             65
# United Arab Emirates               13
# Pakistan                            7
# Lebanon                             7
# Saudi Arabia                        7
# Germany                             5
# Kuwait                              3
# Egypt                               3
# India                               2
# Palestine                           2
# South Africa                        2
# France                              1
# Italy                               1
# Japan                               1
# Libya                               1

# %%
oportunidades_perdidas_middle_east_df_paises_df.plot(kind= 'bar',figsize =(16,8), rot =65, title = 'Paises con casos cerrados perdidos del middle east', color = (0.7, 0.2, 0.4, 0.6));
ax=plt.gca()
ax.set_ylabel('oportunidades cerradas perdidas');
ax.set_xlabel('Paises')
# Out:
# Text(0.5, 0, 'Paises')

# %%
anios_totales = oportunidades_cerradas.Opportunity_Created_Date.dt.year.value_counts().to_frame( name = ' Cantidad de oportunidades creadas').sort_index()
anios_totales
# Out:
#        Cantidad de oportunidades creadas
# 2016                                  15
# 2017                                  84
# 2018                                  71

# %%
anios_ganados = oportunidades_ganadas_middle_east.Opportunity_Created_Date.dt.year.value_counts().to_frame(name = 'Cantidad de oportunidades ganadas creadas').sort_index()
anios_ganados
# Out:
#       Cantidad de oportunidades ganadas creadas
# 2016                                          5
# 2017                                         20
# 2018                                         25

# %%
anios_perdidos = oportunidades_perdidas_middle_east.Opportunity_Created_Date.dt.year.value_counts().to_frame(name = 'Cantidad de oportunidades perdidas').sort_index()
anios_perdidos
# Out:
#       Cantidad de oportunidades perdidas
# 2016                                  10
# 2017                                  64
# 2018                                  46

# %%
lista_anios = [anios_ganados, anios_totales, anios_perdidos]
grafico_anios = pd.concat(lista_anios, join = 'outer', axis = 1).fillna(0)
grafico_anios
# Out:
#       Cantidad de oportunidades ganadas creadas  \
# 2016                                          5
# 2017                                         20
# 2018                                         25
#
#        Cantidad de oportunidades creadas  Cantidad de oportunidades perdidas
# 2016                                  15                                  10
# 2017                                  84                                  64
# 2018                                  71                                  46

# %%
grafico_anios.plot.bar( title = 'Cantidad oportunidades totales, ganadas y perdidas por anio' , rot = 0, figsize = ((20,10)), color = ['green', 'blue', 'red'])
plt.show()

# %%
vendedores_totales = oportunidades_cerradas.Account_Owner.value_counts().to_frame(name = 'Oportunidades creadas po vendedor')
vendedores_totales
# Out:
#                 Oportunidades creadas po vendedor
# Person_Name_5                                 146
# Person_Name_39                                  7
# Person_Name_13                                  5
# Person_Name_62                                  5
# Person_Name_34                                  3
# Person_Name_41                                  1
# Person_Name_2                                   1
# Person_Name_60                                  1
# Person_Name_66                                  1

# %%
vendedores_ganados = oportunidades_ganadas_middle_east.Account_Owner.value_counts().to_frame(name = 'Oportunidades ganadas por vendedor')
vendedores_ganados
# Out:
#                 Oportunidades ganadas por vendedor
# Person_Name_5                                   44
# Person_Name_13                                   3
# Person_Name_39                                   2
# Person_Name_34                                   1

# %%
vendedores_perdidos = oportunidades_perdidas_middle_east.Account_Owner.value_counts().to_frame(name = 'Oportunidades perdidas por vendedor')
vendedores_perdidos
# Out:
#                 Oportunidades perdidas por vendedor
# Person_Name_5                                   102
# Person_Name_39                                    5
# Person_Name_62                                    5
# Person_Name_34                                    2
# Person_Name_13                                    2
# Person_Name_2                                     1
# Person_Name_60                                    1
# Person_Name_66                                    1
# Person_Name_41                                    1

# %%
ventas_totales_vendedores = [vendedores_ganados, vendedores_totales, vendedores_perdidos]
grafico_vendedores =  pd.concat(ventas_totales_vendedores, join = 'outer', axis = 1).fillna(0).nlargest(5, 'Oportunidades ganadas por vendedor')
grafico_vendedores
# Out:
#                 Oportunidades ganadas por vendedor  \
# Person_Name_5                                 44.0
# Person_Name_13                                 3.0
# Person_Name_39                                 2.0
# Person_Name_34                                 1.0
# Person_Name_62                                 0.0
#
#                 Oportunidades creadas po vendedor  \
# Person_Name_5                                 146
# Person_Name_13                                  5
# Person_Name_39                                  7
# Person_Name_34                                  3
# Person_Name_62                                  5
#
#                 Oportunidades perdidas por vendedor
# Person_Name_5                                   102
# Person_Name_13                                    2
# Person_Name_39                                    5
# Person_Name_34                                    2
# Person_Name_62                                    5

# %%
grafico_vendedores.plot.barh( title = 'Top 5 vendedores ventas totales por cantidad de oportunidades ganadas' , rot = 0, figsize = ((15,10)), color = ['green', 'blue', 'red'])
ax=plt.gca()
ax.set_ylabel('Vendedores');
ax.set_xlabel('Cantidad de oportunidades')
plt.show()
