# %%
import pandas as pd
import numpy as np
import datetime as datetime
import calendar
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-102-abcb6dd3bc1a> in <module>
# ----> 1 from wordcloud import WordCloud
#       2 import pandas as pd
#       3 import numpy as np
#       4 import datetime as datetime
#       5 import calendar
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
df = pd.read_csv('C:/Users/ramil/Documents/UBA/(75.06) Organización de Datos/TPS/TP1/Entrenamieto_ECI_2020.csv')

# %% [markdown]
# # Cantidad de impuesto por Territorio

# %%
total_pagado_territorio = df[['Territory', 'Total_Amount', 'Total_Amount_Currency', 'Total_Taxable_Amount', 'Total_Taxable_Amount_Currency']]
total_pagado_territorio = total_pagado_territorio.loc[total_pagado_territorio['Territory'] != 'None']
total_pagado_territorio
# Out:
#         Territory  Total_Amount Total_Amount_Currency  Total_Taxable_Amount  \
# 2      NW America      83865.60                   USD               83865.6
# 3      NW America    7421881.50                   USD             7421881.5
# 4      NW America   13357192.50                   USD            13357192.5
# 5      NW America   14838277.50                   USD            14838277.5
# 6      NW America    2659494.60                   USD             2659494.6
# ...           ...           ...                   ...                   ...
# 16942     Austria     103350.00                   EUR              299715.0
# 16943     Austria      93015.00                   EUR              299715.0
# 16944     Austria     103350.00                   EUR              299715.0
# 16945  NE America    2346796.88                   USD                   0.0
# 16946  NE America   25603200.00                   USD                   0.0
#
#       Total_Taxable_Amount_Currency
# 2                               USD
# 3                               USD
# 4                               USD
# 5                               USD
# 6                               USD
# ...                             ...
# 16942                           EUR
# 16943                           EUR
# 16944                           EUR
# 16945                           USD
# 16946                           USD
#
# [11948 rows x 5 columns]

# %% [markdown]
# Elimino aquellas filas que posean un precio final menor o igual a 0

# %%
total_pagado_territorio = total_pagado_territorio.loc[total_pagado_territorio['Total_Taxable_Amount'] > 0.0]
total_pagado_territorio
# Out:
#         Territory  Total_Amount Total_Amount_Currency  Total_Taxable_Amount  \
# 2      NW America       83865.6                   USD               83865.6
# 3      NW America     7421881.5                   USD             7421881.5
# 4      NW America    13357192.5                   USD            13357192.5
# 5      NW America    14838277.5                   USD            14838277.5
# 6      NW America     2659494.6                   USD             2659494.6
# ...           ...           ...                   ...                   ...
# 16940  NE America    10751580.0                   USD            21332500.0
# 16941  NE America    10580920.0                   USD            21332500.0
# 16942     Austria      103350.0                   EUR              299715.0
# 16943     Austria       93015.0                   EUR              299715.0
# 16944     Austria      103350.0                   EUR              299715.0
#
#       Total_Taxable_Amount_Currency
# 2                               USD
# 3                               USD
# 4                               USD
# 5                               USD
# 6                               USD
# ...                             ...
# 16940                           USD
# 16941                           USD
# 16942                           EUR
# 16943                           EUR
# 16944                           EUR
#
# [11097 rows x 5 columns]

# %%
impuesto = (total_pagado_territorio['Total_Taxable_Amount'] - total_pagado_territorio['Total_Amount'])/total_pagado_territorio['Total_Taxable_Amount']

# %% [markdown]
# Agrego el impuesto agregado al dataframe

# %%
total_pagado_territorio['Impuesto_agregado_porcentual'] = impuesto
total_pagado_territorio
# Out:
# <ipython-input-93-745a0745c0a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_pagado_territorio['Impuesto_agregado_porcentual'] = impuesto
#         Territory  Total_Amount Total_Amount_Currency  Total_Taxable_Amount  \
# 2      NW America       83865.6                   USD               83865.6
# 3      NW America     7421881.5                   USD             7421881.5
# 4      NW America    13357192.5                   USD            13357192.5
# 5      NW America    14838277.5                   USD            14838277.5
# 6      NW America     2659494.6                   USD             2659494.6
# ...           ...           ...                   ...                   ...
# 16940  NE America    10751580.0                   USD            21332500.0
# 16941  NE America    10580920.0                   USD            21332500.0
# 16942     Austria      103350.0                   EUR              299715.0
# 16943     Austria       93015.0                   EUR              299715.0
# 16944     Austria      103350.0                   EUR              299715.0
#
#       Total_Taxable_Amount_Currency  Impuesto_agregado_porcentual
# 2                               USD                      0.000000
# 3                               USD                      0.000000
# 4                               USD                      0.000000
# 5                               USD                      0.000000
# 6                               USD                      0.000000
# ...                             ...                           ...
# 16940                           USD                      0.496000
# 16941                           USD                      0.504000
# 16942                           EUR                      0.655172
# 16943                           EUR                      0.689655
# 16944                           EUR                      0.655172
#
# [11097 rows x 6 columns]

# %% [markdown]
# Acá vemos aquellos territorios que no aplican impuesto alguno

# %%
cant_impuesto = total_pagado_territorio.groupby('Territory').agg({'Impuesto_agregado_porcentual':'max'})
cant_impuesto.sort_values('Impuesto_agregado_porcentual', ascending = True).head(25)
# Out:
#                  Impuesto_agregado_porcentual
# Territory
# Albania                              0.000000
# Morocco                              0.000000
# Lebanon                              0.000000
# Kuwait                               0.000000
# Kosovo                               0.000000
# Oman                                 0.000000
# Romania                              0.000000
# Slovenia                             0.000000
# Solomon Islands                      0.000000
# Georgia                              0.000000
# South East Asia                      0.000000
# Egypt                                0.000000
# Czech Republic                       0.000000
# Croatia                              0.000000
# Monaco                               0.000000
# Bulgaria                             0.000000
# Tunisia                              0.000000
# UAE (Others)                         0.000000
# Cambodia                             0.000000
# UAE (Dubai)                          0.000000
# Burma                                0.000000
# Sweden                               0.500000
# Belarus                              0.500000
# Malaysia                             0.500087
# Ukraine                              0.504274

# %%
territorios_sin_impuesto = cant_impuesto.loc[cant_impuesto['Impuesto_agregado_porcentual'] == 0]
territorios_sin_impuesto
# Out:
#                  Impuesto_agregado_porcentual
# Territory
# Albania                                   0.0
# Bulgaria                                  0.0
# Burma                                     0.0
# Cambodia                                  0.0
# Croatia                                   0.0
# Czech Republic                            0.0
# Egypt                                     0.0
# Georgia                                   0.0
# Kosovo                                    0.0
# Kuwait                                    0.0
# Lebanon                                   0.0
# Monaco                                    0.0
# Morocco                                   0.0
# Oman                                      0.0
# Romania                                   0.0
# Slovenia                                  0.0
# Solomon Islands                           0.0
# South East Asia                           0.0
# Tunisia                                   0.0
# UAE (Dubai)                               0.0
# UAE (Others)                              0.0

# %%
impuesto_por_territorio = total_pagado_territorio.groupby(['Territory', 'Total_Taxable_Amount_Currency']).agg({'Impuesto_agregado_porcentual':'mean'})

# %%
impuesto_por_territorio = impuesto_por_territorio.reset_index()

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (18, 10)
plt.plot( 'Territory', 'Impuesto_agregado_porcentual', data=impuesto_por_territorio.sort_values('Impuesto_agregado_porcentual', ascending = False).head(15), linestyle='-', marker='o')

# %%
impuesto_por_territorio.loc[impuesto_por_territorio['Territory'] == 'United Kingdom']
# Out:
#          Territory Total_Taxable_Amount_Currency  Impuesto_agregado_porcentual
# 94  United Kingdom                           EUR                      0.258738
# 95  United Kingdom                           GBP                      0.750000
# 96  United Kingdom                           USD                      0.533333

# %% [markdown]
# Se puede ver que la repetición de territorios se debe a la diferencia de impuesto con diferentes monedas
