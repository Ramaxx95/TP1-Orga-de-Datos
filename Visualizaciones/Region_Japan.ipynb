# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_frame = pd.read_csv('Entrenamieto_ECI_2020.csv')
data_frame.Account_Created_Date = pd.to_datetime(data_frame.Account_Created_Date)
data_frame.Actual_Delivery_Date = pd.to_datetime(data_frame.Actual_Delivery_Date)
data_frame.Opportunity_Created_Date = pd.to_datetime(data_frame.Opportunity_Created_Date)
data_frame.Quote_Expiry_Date = pd.to_datetime(data_frame.Quote_Expiry_Date)
data_frame.Last_Modified_Date = pd.to_datetime(data_frame.Last_Modified_Date)
data_frame.Planned_Delivery_Start_Date = pd.to_datetime(data_frame.Planned_Delivery_Start_Date)
data_frame
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0      27761      EMEA        None                                   1
# 1      27760      EMEA        None                                   0
# 2      27446  Americas  NW America                                   0
# 3      16808  Americas  NW America                                   1
# 4      16805  Americas  NW America                                   1
# ...      ...       ...         ...                                 ...
# 16942   8781      EMEA     Austria                                   1
# 16943   8786      EMEA     Austria                                   1
# 16944   8792      EMEA     Austria                                   1
# 16945  28561  Americas  NE America                                   1
# 16946  28318  Americas  NE America                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# ...

# %%
japon_cerrados_ganadas_df = data_frame[(data_frame.Stage == 'Closed Won') & (data_frame.Region == 'Japan')]
japon_cerrados_ganadas_df
# Out:
#           ID Region Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 65     24444  Japan      None                                   1
# 139    23618  Japan     Japan                                   0
# 140    23619  Japan     Japan                                   0
# 141    23614  Japan     Japan                                   0
# 142    23617  Japan     Japan                                   0
# ...      ...    ...       ...                                 ...
# 16922  18519  Japan      None                                   1
# 16923  27689  Japan      None                                   1
# 16924  27688  Japan      None                                   1
# 16925  19062  Japan     Japan                                   0
# 16926  19066  Japan     Japan                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 65                                    1                             0
# ...

# %%
japon_cerrados_perdidas_df = data_frame[(data_frame.Stage == 'Closed Lost') & (data_frame.Region == 'Japan')]
japon_cerrados_perdidas_df
# Out:
#           ID Region Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 8      24353  Japan      None                                   1
# 9      24355  Japan      None                                   1
# 10     24356  Japan      None                                   1
# 11     24357  Japan      None                                   1
# 12     24358  Japan      None                                   1
# ...      ...    ...       ...                                 ...
# 16898  24701  Japan      None                                   1
# 16899  24702  Japan      None                                   1
# 16900  24703  Japan      None                                   1
# 16901  24704  Japan      None                                   1
# 16914  23781  Japan      None                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 8                                     0                             0
# ...

# %%
japon_cerrados_ganadas_df.Account_Created_Date.value_counts()
# Out:
# 2015-04-20    1813
# 2013-09-23     520
# 2015-12-21     323
# 2013-07-28      91
# 2015-10-30      90
# 2015-07-03      56
# 2013-08-11      50
# 2014-12-19      47
# 2016-06-02      39
# 2014-07-24      39
# 2016-08-17      27
# 2017-09-14      25
# 2015-06-11      21
# 2013-11-07      16
# 2015-06-15      16
# 2016-12-16      15
# 2015-02-10      15
# 2016-12-09      14
# 2014-10-13      11
# 2017-06-30      11
# 2016-02-16      11
# 2015-02-13       7
# 2014-08-22       7
# 2016-09-27       6
# 2016-07-05       6
# 2016-08-10       5
# 2018-02-05       4
# 2016-08-26       4
# 2016-05-16       4
# 2017-03-27       3
# 2018-06-29       3
# 2016-11-01       2
# 2018-09-27       2
# 2017-11-20       2
# 2016-02-05       2
# 2017-12-12       2
# 2018-05-23       2
# 2018-12-17       2
# 2018-07-11       2
# 2016-10-18       1
# 2018-08-21       1
# 2018-04-13       1
# 2015-03-13       1
# 2016-10-21       1
# 2018-11-13       1
# 2017-04-18       1
# 2018-12-12       1
# ...

# %%
casos_ganados_japon_2013 = japon_cerrados_ganadas_df[japon_cerrados_ganadas_df.Account_Created_Date.dt.year == 2013].Account_Created_Date.value_counts()
casos_ganados_japon_iniciados_2013_df = casos_ganados_japon_2013.to_frame()
casos_ganados_japon_iniciados_2013_df.columns = ['Cantidad de casos abiertos en la fecha']
casos_ganados_japon_iniciados_2013_df
# Out:
#             Cantidad de casos abiertos en la fecha
# 2013-09-23                                     520
# 2013-07-28                                      91
# 2013-08-11                                      50
# 2013-11-07                                      16

# %%
casos_ganados_japon_iniciados_2013_df.plot(kind = 'bar', figsize =(16,8), rot =0, title = 'Cantidad de casos ganados abiertos en el 2013', color = (0.7, 0.2, 0.4, 0.6));
ax=plt.gca()
ax.set_ylabel('Cantidad de casos abiertos');
ax.set_xlabel('Fecha')
# Out:
# Text(0.5, 0, 'Fecha')

# %%
japon_cerrados_perdidas_df.Delivery_Year.value_counts()
# Out:
# 2016    1147
# 2017     224
# 2018     126
# 2019      49
# Name: Delivery_Year, dtype: int64

# %%
casos_perdidos_japon_2013_df = japon_cerrados_perdidas_df[japon_cerrados_perdidas_df.Account_Created_Date.dt.year == 2013]
casos_perdidos_japon_2013_df
# Out:
#           ID Region Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 3063   16725  Japan      None                                   1
# 3386   22805  Japan     Japan                                   1
# 4119   18895  Japan      None                                   1
# 5304   18569  Japan      None                                   1
# 5305   18892  Japan      None                                   1
# ...      ...    ...       ...                                 ...
# 15603  21492  Japan     Japan                                   1
# 15642  23082  Japan     Japan                                   1
# 15890  21433  Japan     Japan                                   1
# 15891  21792  Japan     Japan                                   1
# 15934  18782  Japan      None                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 3063                                  1                             1
# ...

# %%
grafico_casos_perdidos_creados_2013_df = casos_perdidos_japon_2013_df.Account_Created_Date.value_counts().to_frame()
grafico_casos_perdidos_creados_2013_df.columns=['Cantidad de casos abiertos en la fecha']
grafico_casos_perdidos_creados_2013_df
# Out:
#             Cantidad de casos abiertos en la fecha
# 2013-09-23                                      66
# 2013-07-28                                      21
# 2013-08-11                                       5
# 2013-11-07                                       2
# 2013-10-03                                       1

# %%
grafico_casos_perdidos_creados_2013_df.plot(kind = 'bar', figsize =(16,8), rot =0, title = 'Cantidad de casos perdidos abiertos 2013', color = (0.7, 0.2, 0.4, 0.6));
ax=plt.gca()
ax.set_ylabel('Cantidad de casos abiertos');
ax.set_xlabel('Fecha')
# Out:
# Text(0.5, 0, 'Fecha')
